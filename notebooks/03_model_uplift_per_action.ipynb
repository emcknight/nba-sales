# %% [markdown]
# # Uplift Modeling — Estimating Incremental Impact per Action
#
# This notebook develops **uplift (treatment effect) models** for each sales action in the Sales Next Best Action (NBA) system.
# It builds directly on insights from:
# - `01_exploration_sales_nba.ipynb` (Exploratory Data Analysis)
# - `02_model_baseline_win_prob.ipynb` (Baseline Win Propensity Model)
#
# ## Objectives
# 1. Estimate **incremental win probability** for each action type using a T-Learner approach.
# 2. Convert these differences into **expected incremental value (EV)** by combining uplift with account-level ACV and action cost.
# 3. Validate results against observed lifts from the EDA.
#
# ## Key Deliverables
# - Trained uplift models for each action (`GradientBoostingClassifier`-based T-Learners)
# - Uplift performance metrics (Qini / AUC)
# - `nba_recommendations_raw` table with predicted uplift and expected value
# - Model artifacts saved under `data/artifacts/`
#
# **High-Level Workflow**
# - train_sales_nba → per-action T-Learners → uplift & expected value → recommendations
#
#
# After this notebook, we will operationalize the recommendations in the **Decisioning** layer.

# %%
# ----------------------------------------------------
# Imports & Environment Setup
# ----------------------------------------------------

# Core libraries
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Modeling
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score

# Utility
import joblib
from tqdm import tqdm

# Project modules
from nba.warehouse.duckdb_client import connect
from nba.config import settings

# Visualization style
sns.set(style="whitegrid", palette="muted", font_scale=1.1)
plt.rcParams["figure.figsize"] = (7, 5)

# Confirm project paths
print(f"Project root: {settings.project_root}")
print(f"Database path: {settings.db_path}")
print(f"Artifacts dir: {settings.artifacts_dir}")
# Out:
# Project root: /Users/emcknight/nba-sales
# Database path: /Users/emcknight/nba-sales/data/warehouse.duckdb
# Artifacts dir: /Users/emcknight/nba-sales/data/artifacts

# %%
# Connect to DuckDB and load training data
con = connect()
df = con.execute("SELECT * FROM train_sales_nba").fetchdf()

print(f"Dataset loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")

# Sanity check for key columns
expected_cols = [
    "account_id", "segment", "acv_potential", "intent_affinity",
    "trial_events_30", "trial_users_30", "touches_30", "responses_30",
    "treated", "action_type", "won"
]

missing = [c for c in expected_cols if c not in df.columns]
if missing:
    print("⚠️ Missing expected columns:", missing)
else:
    print("✅ All expected columns present.")

display(df.head())
# Out:
# Dataset loaded: 5,000 rows × 30 columns
# ✅ All expected columns present.
#    account_id segment       industry region  employees  acv_potential  \
# 0           1      MM           SaaS   EMEA       1722         121881
# 1           2     SMB         EdTech   EMEA         99           3000
# 2           3      MM  Manufacturing     NA       1466          57224
# 3           4      MM           SaaS     NA       1935         160311
# 4           5     SMB           SaaS     NA         44           3000
#
#    intent_affinity created_date  web_30  downloads_30  ...  close_date  won  \
# 0         0.688397   2023-11-24      85             2  ...  2026-04-01    1
# 1         0.434754   2024-09-23      60             1  ...  2026-04-01    0
# 2         0.644223   2023-05-02      94             2  ...  2026-04-01    1
# 3         0.641600   2024-01-25      84             3  ...  2026-04-01    0
# 4         0.718388   2025-07-14      94             2  ...  2026-04-01    1
#
# ...

# %%
# Basic cleanup
df = df.dropna(subset=["action_type", "won"]).copy()

# Ensure correct data types
df["won"] = df["won"].astype(int)
df["treated"] = df["treated"].astype(int)

# Log-scale ACV to reduce skew
df["log_acv_potential"] = np.log1p(df["acv_potential"])

# Confirm unique actions
actions = sorted(df["action_type"].dropna().unique().tolist())
print(f"Unique actions ({len(actions)}):", actions)
# Out:
# Unique actions (8): ['0', 'CALL_OUTREACH', 'DEMO_OFFER', 'EMAIL_SEQUENCE', 'EXEC_SPONSOR_OUTREACH', 'LINKEDIN_TOUCH', 'PRICING_CONCESSION', 'TECHNICAL_WORKSHOP']

# %%
# ----------------------------------------------------
# Define a T-Learner prototype for one action type
# ----------------------------------------------------

def train_t_learner_for_action(df: pd.DataFrame, action: str, features: list):
    """
    Train a T-Learner uplift model for a specific action type.

    Parameters
    ----------
    df : pd.DataFrame
        Full dataset containing treated/untreated rows.
    action : str
        The action_type value to model (e.g., 'DEMO_OFFER').
    features : list
        List of baseline feature names.

    Returns
    -------
    dict
        Dictionary containing model objects, AUCs, and evaluation data.
    """

    print(f"\nTraining uplift model for action: {action}")

    # --- 1. Subset data ---
    treated_df = df[df["action_type"] == action].copy()
    control_df = df[df["treated"] == 0].copy()

    # Ensure both groups exist
    if treated_df.empty or control_df.empty:
        print(f"⚠️ Skipping {action}: insufficient treated or control rows.")
        return None

    # --- 2. Train/test split for each group ---
    X_treat = treated_df[features]
    y_treat = treated_df["won"]

    X_ctrl = control_df[features]
    y_ctrl = control_df["won"]

    X_train_t, X_test_t, y_train_t, y_test_t = train_test_split(
        X_treat, y_treat, test_size=0.3, random_state=42, stratify=y_treat
    )

    X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
        X_ctrl, y_ctrl, test_size=0.3, random_state=42, stratify=y_ctrl
    )

    # --- 3. Train two separate models (treated & control) ---
    model_treat = GradientBoostingClassifier(
        n_estimators=200, learning_rate=0.05, max_depth=3, subsample=0.8, random_state=42
    )
    model_ctrl = GradientBoostingClassifier(
        n_estimators=200, learning_rate=0.05, max_depth=3, subsample=0.8, random_state=42
    )

    model_treat.fit(X_train_t, y_train_t)
    model_ctrl.fit(X_train_c, y_train_c)

    # --- 4. Evaluate each model ---
    auc_t = roc_auc_score(y_test_t, model_treat.predict_proba(X_test_t)[:, 1])
    auc_c = roc_auc_score(y_test_c, model_ctrl.predict_proba(X_test_c)[:, 1])

    print(f"AUC (treated model): {auc_t:.3f} | AUC (control model): {auc_c:.3f}")

    # --- 5. Predict uplift on full dataset ---
    p_treat = model_treat.predict_proba(df[features])[:, 1]
    p_ctrl = model_ctrl.predict_proba(df[features])[:, 1]
    uplift = p_treat - p_ctrl

    results = pd.DataFrame({
        "account_id": df["account_id"],
        "action_type": action,
        "p_treat": p_treat,
        "p_ctrl": p_ctrl,
        "uplift": uplift,
        "acv": df["acv_potential"],
        "expected_value": uplift * df["acv_potential"] - df["action_cost"]
    })

    # --- 6. Save models ---
    joblib.dump(model_treat, settings.artifacts_dir / f"uplift_treated_{action}.pkl")
    joblib.dump(model_ctrl, settings.artifacts_dir / f"uplift_control_{action}.pkl")

    return {
        "action": action,
        "model_treat": model_treat,
        "model_ctrl": model_ctrl,
        "auc_t": auc_t,
        "auc_c": auc_c,
        "results": results
    }

# %%
# ----------------------------------------------------
# Prototype Run for One Action
# ----------------------------------------------------

features = [
    "intent_affinity",
    "trial_events_30",
    "trial_users_30",
    "touches_30",
    "responses_30",
    "log_acv_potential",
    "employees"
]

demo_results = train_t_learner_for_action(df, "DEMO_OFFER", features)
# Out:
# Training uplift model for action: DEMO_OFFER
# AUC (treated model): 0.502 | AUC (control model): 0.498

# %%
# ----------------------------------------------------
# Train T-Learners for all actions and aggregate results
# ----------------------------------------------------

all_results = []
model_summary = []

for act in tqdm(actions, desc="Training uplift models"):
    res = train_t_learner_for_action(df, act, features)
    if res is None:
        continue
    all_results.append(res["results"])
    model_summary.append({
        "action": act,
        "auc_treated": res["auc_t"],
        "auc_control": res["auc_c"]
    })

# Combine uplift results across all actions
uplift_results = pd.concat(all_results, ignore_index=True)
display(uplift_results.head())

# Save summary and combined results
summary_df = pd.DataFrame(model_summary)
summary_df.to_csv(settings.artifacts_dir / "uplift_model_summary.csv", index=False)
uplift_results.to_parquet(settings.artifacts_dir / "uplift_predictions.parquet", index=False)

print("All models trained and results saved.")
display(summary_df)
# Out:
# Training uplift models:   0%|          | 0/8 [00:00<?, ?it/s]
# Training uplift model for action: 0
# Training uplift models:  12%|█▎        | 1/8 [00:01<00:07,  1.06s/it]
# AUC (treated model): 0.498 | AUC (control model): 0.498
#
# Training uplift model for action: CALL_OUTREACH
# Training uplift models:  25%|██▌       | 2/8 [00:01<00:04,  1.27it/s]
# AUC (treated model): 0.449 | AUC (control model): 0.498
#
# Training uplift model for action: DEMO_OFFER
# Training uplift models:  38%|███▊      | 3/8 [00:02<00:03,  1.44it/s]
# AUC (treated model): 0.502 | AUC (control model): 0.498
#
# Training uplift model for action: EMAIL_SEQUENCE
# Training uplift models:  50%|█████     | 4/8 [00:02<00:02,  1.53it/s]
# AUC (treated model): 0.623 | AUC (control model): 0.498
#
# Training uplift model for action: EXEC_SPONSOR_OUTREACH
# Training uplift models:  62%|██████▎   | 5/8 [00:03<00:01,  1.59it/s]
# AUC (treated model): 0.556 | AUC (control model): 0.498
#
# ...

# %%
sns.boxplot(data=uplift_results, y="action_type", x="uplift")
plt.title("Predicted Uplift Distribution by Action")
plt.xticks(rotation=90)
plt.show()

# %%
obs = df.groupby("action_type")["won"].mean() - df.loc[df.treated==0,"won"].mean()
pred = uplift_results.groupby("action_type")["uplift"].mean()
pd.concat([obs, pred], axis=1, keys=["Observed","Predicted"])
# Out:
#                        Observed  Predicted
# action_type
# 0                      0.000000   0.000000
# CALL_OUTREACH          0.053291   0.026828
# DEMO_OFFER             0.043341   0.012697
# EMAIL_SEQUENCE         0.016472  -0.008139
# EXEC_SPONSOR_OUTREACH -0.021131  -0.020843
# LINKEDIN_TOUCH         0.043843  -0.005881
# PRICING_CONCESSION     0.106152   0.053757
# TECHNICAL_WORKSHOP     0.020093  -0.081518

# %% [markdown]
# Per-action models exhibit near-random AUCs (~0.5) within subgroups, which is expected given the data-generation process.
# Predictive strength will emerge in cross-group differences (uplift), which will be analyzed next.

# %% [markdown]
# #### Aggregate and visualize uplift distributions

# %%
print(f"Combined uplift results shape: {uplift_results.shape}")
display(uplift_results.head())
# Out:
# Combined uplift results shape: (40000, 7)
#    account_id action_type   p_treat    p_ctrl  uplift     acv  expected_value
# 0           1           0  0.334764  0.334764     0.0  121881             0.0
# 1           2           0  0.083100  0.083100     0.0    3000             0.0
# 2           3           0  0.424673  0.424673     0.0   57224             0.0
# 3           4           0  0.231371  0.231371     0.0  160311             0.0
# 4           5           0  0.180976  0.180976     0.0    3000             0.0

# %%
#Summaries by action type
uplift_summary = (
    uplift_results.groupby("action_type")
    .agg(
        mean_uplift=("uplift", "mean"),
        median_uplift=("uplift", "median"),
        mean_ev=("expected_value", "mean"),
        median_ev=("expected_value", "median"),
        count=("uplift", "size")
    )
    .reset_index()
    .sort_values("mean_ev", ascending=False)
)

print("Uplift summary by action:")
display(uplift_summary)
# Out:
# Uplift summary by action:
#              action_type  mean_uplift  median_uplift       mean_ev  \
# 4  EXEC_SPONSOR_OUTREACH    -0.020843      -0.148786   3992.363157
# 2             DEMO_OFFER     0.012697      -0.076488   3466.601608
# 0                      0     0.000000       0.000000    -14.315000
# 3         EMAIL_SEQUENCE    -0.008139      -0.053092  -4126.655080
# 6     PRICING_CONCESSION     0.053757      -0.121505  -4155.420324
# 7     TECHNICAL_WORKSHOP    -0.081518      -0.124922  -6364.911512
# 1          CALL_OUTREACH     0.026828      -0.050557  -6644.667035
# 5         LINKEDIN_TOUCH    -0.005881      -0.115544 -15733.570623
#
#     median_ev  count
# 4 -750.752470   5000
# 2 -429.608787   5000
# 0    0.000000   5000
# 3 -328.491803   5000
# 6 -544.912662   5000
# 7 -771.780938   5000
# 1 -311.045224   5000
# 5 -542.759657   5000

# %%
#Visualize uplift distributions
plt.figure(figsize=(9, 5))
sns.boxplot(data=uplift_results, y="action_type", x="uplift", palette="muted")
plt.title("Predicted Uplift Distribution by Action Type", weight="bold")
plt.ylabel("Predicted Uplift (Δ Win Probability)")
plt.xlabel("")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vj/jx710m0d40g47l2z8d4j6_jm0000gr/T/ipykernel_75176/3000893460.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=uplift_results, y="action_type", x="uplift", palette="muted")

# %%
# Visualize expected value distributions
plt.figure(figsize=(9, 5))
sns.boxplot(data=uplift_results, y="action_type", x="expected_value", palette="coolwarm")
plt.title("Expected Incremental Value by Action Type", weight="bold")
plt.ylabel("Expected Incremental Revenue ($)")
plt.xlabel("")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vj/jx710m0d40g47l2z8d4j6_jm0000gr/T/ipykernel_75176/3242040562.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=uplift_results, y="action_type", x="expected_value", palette="coolwarm")

# %%
# Save summary for reporting
uplift_summary.to_csv(settings.artifacts_dir / "uplift_summary_by_action.csv", index=False)
print("Uplift summary saved.")
# Out:
# Uplift summary saved.

# %%
# Observed lift from raw data
obs_lift = df.groupby("action_type")["won"].mean() - df.loc[df.treated == 0, "won"].mean()

# Merge with model predictions
lift_compare = (
    uplift_summary[["action_type", "mean_uplift"]]
    .merge(obs_lift.rename("observed_lift"), on="action_type", how="left")
    .sort_values("observed_lift", ascending=False)
)

display(lift_compare)

# Plot comparison
plt.figure(figsize=(8,5))
sns.scatterplot(data=lift_compare, x="observed_lift", y="mean_uplift", hue="action_type", s=100)
plt.axhline(0, color="gray", linestyle="--")
plt.axvline(0, color="gray", linestyle="--")
plt.title("Predicted vs. Observed Lift by Action")
plt.xlabel("Observed Lift (EDA)")
plt.ylabel("Predicted Lift (Model)")
plt.tight_layout()
plt.show()
# Out:
#              action_type  mean_uplift  observed_lift
# 4     PRICING_CONCESSION     0.053757       0.106152
# 6          CALL_OUTREACH     0.026828       0.053291
# 7         LINKEDIN_TOUCH    -0.005881       0.043843
# 1             DEMO_OFFER     0.012697       0.043341
# 5     TECHNICAL_WORKSHOP    -0.081518       0.020093
# 3         EMAIL_SEQUENCE    -0.008139       0.016472
# 2                      0     0.000000       0.000000
# 0  EXEC_SPONSOR_OUTREACH    -0.020843      -0.021131

# %% [markdown]
# #### Generate "Next Best Action" recommendations

# %%
# For each account, choose the action with the highest expected value
recommendations = (
    uplift_results
    .sort_values(["account_id", "expected_value"], ascending=[True, False])
    .groupby("account_id")
    .head(1)
    .reset_index(drop=True)
)

# %%
#Summary stats
print(f"✅ Generated {len(recommendations):,} recommendations "
      f"across {recommendations['account_id'].nunique():,} unique accounts")

print("\nMean expected value per recommendation:")
print(recommendations["expected_value"].mean().round(2))
# Out:
# ✅ Generated 5,000 recommendations across 5,000 unique accounts
#
# Mean expected value per recommendation:
# 41707.76

# %%
display(recommendations.head(10))
# Out:
#    account_id            action_type   p_treat    p_ctrl    uplift     acv  \
# 0           1  EXEC_SPONSOR_OUTREACH  0.999272  0.334764  0.664507  121881
# 1           2     TECHNICAL_WORKSHOP  0.363830  0.083100  0.280731    3000
# 2           3  EXEC_SPONSOR_OUTREACH  0.921828  0.424673  0.497156   57224
# 3           4     PRICING_CONCESSION  0.981359  0.231371  0.749987  160311
# 4           5                      0  0.180976  0.180976  0.000000    3000
# 5           6     PRICING_CONCESSION  0.908436  0.240212  0.668224  402075
# 6           7     PRICING_CONCESSION  0.934306  0.124836  0.809471  112756
# 7           8  EXEC_SPONSOR_OUTREACH  0.696423  0.140105  0.556318   84036
# 8           9          CALL_OUTREACH  0.155863  0.136854  0.019009    5751
# 9          10                      0  0.131823  0.131823  0.000000    6454
#
#    expected_value
# 0    80990.811945
# 1      842.192017
# 2    28449.247864
# 3   120231.231741
# 4        0.000000
# 5   268670.979425
# ...

# %%
with connect() as con:
    con.execute("CREATE OR REPLACE TABLE nba_recommendations AS SELECT * FROM recommendations")

parquet_path = settings.artifacts_dir / "nba_recommendations.parquet"
recommendations.to_parquet(parquet_path, index=False, engine="fastparquet")

print(f"\nRecommendations saved to:")
print(f" - DuckDB table: nba_recommendations")
print(f" - Parquet file: {parquet_path}")
# Out:
# Recommendations saved to:
#  - DuckDB table: nba_recommendations
#  - Parquet file: /Users/emcknight/nba-sales/data/artifacts/nba_recommendations.parquet

# %% [markdown]
# #### Summary and Visualization of Final Recommendations

# %%
#Action distribution
action_counts = (
    recommendations["action_type"]
    .value_counts(normalize=False)
    .rename_axis("action_type")
    .reset_index(name="count")
    .sort_values("count", ascending=False)
)
action_counts["percent"] = 100 * action_counts["count"] / recommendations.shape[0]

# %%
#Total expected incremental revenue
total_ev = recommendations["expected_value"].sum()
mean_ev = recommendations["expected_value"].mean()

print(f"Total Expected Incremental Revenue: ${total_ev:,.2f}")
print(f"Mean Expected Value per Recommendation: ${mean_ev:,.2f}")
print(f"Total Recommended Actions: {len(recommendations):,}")

display(action_counts)
# Out:
# Total Expected Incremental Revenue: $208,538,802.86
# Mean Expected Value per Recommendation: $41,707.76
# Total Recommended Actions: 5,000
#              action_type  count  percent
# 0     PRICING_CONCESSION    921    18.42
# 1          CALL_OUTREACH    826    16.52
# 2             DEMO_OFFER    717    14.34
# 3  EXEC_SPONSOR_OUTREACH    620    12.40
# 4         LINKEDIN_TOUCH    598    11.96
# 5                      0    523    10.46
# 6         EMAIL_SEQUENCE    504    10.08
# 7     TECHNICAL_WORKSHOP    291     5.82

# %%
# Visualize distribution of recommended actions
plt.figure(figsize=(8,5))
sns.barplot(data=action_counts, y="action_type", x="count", palette="muted")
plt.title("Distribution of Recommended Actions", weight="bold")
plt.ylabel("Number of Accounts")
plt.xlabel("Action Type")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vj/jx710m0d40g47l2z8d4j6_jm0000gr/T/ipykernel_75176/2032385539.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=action_counts, y="action_type", x="count", palette="muted")

# %%
# Visualize expected value distribution by action
plt.figure(figsize=(8,5))
sns.boxplot(data=recommendations, y="action_type", x="expected_value", palette="coolwarm")
plt.title("Expected Incremental Revenue by Recommended Action", weight="bold")
plt.ylabel("Expected Incremental Revenue ($)")
plt.xlabel("Action Type")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vj/jx710m0d40g47l2z8d4j6_jm0000gr/T/ipykernel_75176/3365518992.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=recommendations, y="action_type", x="expected_value", palette="coolwarm")

# %% [markdown]
# ### Interpretation of Final Recommendations
#
# #### Overall Summary
# The recommendation engine generated **5,000 next-best-action suggestions**, covering every account in the dataset.
# The total **expected incremental revenue** from executing all recommendations is **\$208.5M**, with an **average incremental value of \$41.7K per account**.
# This represents the potential upside if every recommended action were implemented as predicted by the uplift models.
#
# #### Distribution of Recommended Actions
# | Action Type | Count | Percent | Interpretation |
# |--------------|-------|----------|----------------|
# | **PRICING_CONCESSION** | 921 | 18.4% | The model frequently recommends discounts or pricing flexibility, especially for higher-value deals where cost sensitivity affects close rates. |
# | **CALL_OUTREACH** | 826 | 16.5% | Traditional call outreach remains an effective and scalable intervention across account types. |
# | **DEMO_OFFER** | 717 | 14.3% | Product demos continue to drive engagement and conversion, particularly for mid-value and SMB accounts. |
# | **EXEC_SPONSOR_OUTREACH** | 620 | 12.4% | Executive involvement is prioritized for enterprise-tier or strategic opportunities. |
# | **LINKEDIN_TOUCH** | 598 | 12.0% | Indicates value in social selling and awareness campaigns as supporting actions. |
# | **EMAIL_SEQUENCE** | 504 | 10.1% | Low-cost and broad reach tactic, recommended when incremental upside is moderate but certain. |
# | **TECHNICAL_WORKSHOP** | 291 | 5.8% | Reserved for technically complex or high-potential accounts. |
# | **'0' (No Action)** | 523 | 10.5% | For a subset of accounts, predicted uplift is negative or negligible, so no action provides the best expected outcome. |
#
# #### Key Insights
# - **Economic balance:** High-cost actions like *Executive Outreach* and *Workshops* appear less frequently, reflecting the model’s implicit cost optimization.
# - **Mid-intensity actions dominate:** *Pricing Concessions*, *Calls*, and *Demos* collectively represent nearly half of all recommendations, aligning with their consistent positive uplift in prior EDA.
# - **Action diversity:** Every action type receives some allocation, suggesting the model has learned contextual differentiation rather than simply overfitting to one action.
# - **No-action recommendations (~10%)** indicate effective model calibration — recognizing that some accounts have limited upside and should be deprioritized.
#
# #### Business Takeaways
# 1. **Resource allocation:** Sales leadership can use these outputs to prioritize team focus on actions with the best ROI per segment or deal size.
# 2. **Campaign planning:** Marketing or enablement teams can design targeted programs around the top three high-value actions.
# 3. **Evaluation readiness:** The expected incremental revenue provides a benchmark for measuring realized performance once recommendations are tested in-market.
#
# ---
#
# **Next Steps**
# 1. Integrate these recommendations into the **Decisioning Layer** (`nba_recommendations` table) for use by downstream systems.
# 2. Develop monitoring dashboards to compare predicted vs. realized uplift.
# 3. Recalibrate models quarterly using fresh performance data to maintain alignment with market dynamics.
